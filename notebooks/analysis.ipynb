# %%
#Import libraries:
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
plt.rcdefaults()
# %matplotlib inline

# %%
#Import clean data:
        #I used two datasets because joining the complete clean dataset with the scraping lost a lot of information

df1 = pd.read_csv('/Users/MIGUEL/Desktop/CLAB1/Ironhack-Module-1-Project---Pipelines-/data/processed/df_clean.csv')
df2 = pd.read_csv('/Users/MIGUEL/Desktop/CLAB1/Ironhack-Module-1-Project---Pipelines-/data/processed/df_project2CLEAN.csv')

display(df1)
display(df2)
# Out:
#       worth BUSD   worthChange millions USD  age  gender        country  \
# 0            112                          0   54    male           none
# 1             90                          0   62    none  united states
# 2             84                          0   87    male  united states
# 3             72                          0   69    none           none
# 4             71                          0   35    male           none
# ...          ...                        ...  ...     ...            ...
# 2203           1                          0   51    none          china
# 2204           1                          0   55    male           none
# 2205           1                          0   51    none          china
# 2206           1                          0   52  female           none
# 2207           1                          0   54    none           none
#
#                                                   image             name  \
# 0     https://specials-images.forbesimg.com/imageser...       jeff bezos
# 1     https://specials-images.forbesimg.com/imageser...       bill gates
# 2     https://specials-images.forbesimg.com/imageser...   warren buffett
# 3     https://specials-images.forbesimg.com/imageser...  bernard arnault
# 4     https://specials-images.forbesimg.com/imageser...  mark zuckerberg
# ...                                                 ...              ...
# 2203  https://specials-images.forbesimg.com/imageser...   zhao xiaoqiang
# 2204  https://specials-images.forbesimg.com/imageser...  zhou liangzhang
# 2205  https://specials-images.forbesimg.com/imageser...     zhu xingming
# 2206  https://specials-images.forbesimg.com/imageser...         zhuo jun
# 2207  https://specials-images.forbesimg.com/imageser...      olgun zorlu
#
#       position       professional sector                 company
# 0            1               technology                   amazon
# 1            2               technology                microsoft
# 2            3  finance and investments       berkshire hathaway
# 3            4         fashion & retail                     lvmh
# 4            5               technology                 facebook
# ...        ...                       ...                     ...
# 2203      2204         fashion & retail   fashion, entertainment
# 2204      2205            manufacturing     electrical equipment
# 2205      2206            manufacturing     electrical equipment
# 2206      2207            manufacturing   printed circuit boards
# 2207      2208              diversified              diversified
#
# [2208 rows x 10 columns]
#     Rank  country     Population  % of World Population         Date  \
# 0      1    China  1,400,825,000                  18.1%  10 Jan 2020
# 1      1    China  1,400,825,000                  18.1%  10 Jan 2020
# 2      1    China  1,400,825,000                  18.1%  10 Jan 2020
# 3      1    China  1,400,825,000                  18.1%  10 Jan 2020
# 4      1    China  1,400,825,000                  18.1%  10 Jan 2020
# ..   ...      ...            ...                    ...          ...
# 646  136    Qatar      2,747,282                0.0354%  30 Sep 2019
# 647  157   Cyprus        875,900                0.0113%  31 Dec 2018
# 648  157   Cyprus        875,900                0.0113%  31 Dec 2018
# 649  157   Cyprus        875,900                0.0113%  31 Dec 2018
# 650  171  Iceland        362,860               0.00468%  30 Sep 2019
#
#                              Source_x age  gender  \
# 0           National population clock  55    Male
# 1           National population clock  48    None
# 2           National population clock  48    Male
# 3           National population clock  72    Male
# 4           National population clock  51    None
# ..                                ...  ..     ...
# 646    Monthly National estimate[128]  58    None
# 647     National annual estimate[148]  51    None
# 648     National annual estimate[148]  47  Female
# 649     National annual estimate[148]  63    None
# 650  National quarterly estimate[162]  51    None
#
#                                                  image  \
# 0    https://specials-images.forbesimg.com/imageser...
# 1    https://specials-images.forbesimg.com/imageser...
# 2    https://specials-images.forbesimg.com/imageser...
# 3    https://specials-images.forbesimg.com/imageser...
# 4    https://specials-images.forbesimg.com/imageser...
# ..                                                 ...
# 646  https://specials-images.forbesimg.com/imageser...
# 647  https://specials-images.forbesimg.com/imageser...
# 648  https://specials-images.forbesimg.com/imageser...
# 649  https://specials-images.forbesimg.com/imageser...
# 650  https://specials-images.forbesimg.com/imageser...
#
#                                     name  position  \
# 0                               li shufu        92
# 1                                lei jun       118
# 2                           pan zhengmin       156
# 3                           zong qinghou       161
# 4                         guo guangchang       187
# ..                                   ...       ...
# 646  hamad bin jassim bin jaber al thani      1867
# 647                 stelios haji-ioannou      1506
# 648                  clelia haji-ioannou      1779
# 649                 surendra hiranandani      1784
# 650                    thor bjorgolfsson      1219
#
#                                      Source_y  worth BUSD  \
# 0                 Automotive  ==> automobiles          15
# 1                 Technology  ==> smartphones          12
# 2                 Technology  ==> electronics           9
# 3            Food and Beverage  ==> beverages           9
# 4               Diversified  ==> conglomerate           8
# ..                                        ...         ...
# 646  Finance and Investments  ==> investments           1
# 647                      Service  ==> EasyJet           1
# 648                      Service  ==> EasyJet           1
# 649              Real Estate  ==> real estate           1
# 650              Diversified  ==> investments           2
#
#       worthChange millions USD
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ..                         ...
# 646                          0
# 647                          0
# 648                          0
# 649                          0
# 650                          0
#
# [651 rows x 14 columns]

# %%
#Graphic_1: Wealth distribution
graphic_1 = df1['worth BUSD'].hist(bins=100, figsize=(16,8))
plt.xlabel('Position')
plt.ylabel('Wealth')
plt.title("Wealth distribution")
plt.savefig("Wealth distribution")

# %%
#Graphic_2: Scattter - Wealth distribution
Graphic_2 = df1.plot("position", "worth BUSD", kind="scatter")
plt.savefig("Scattter - Wealth distribution")

# %%
#Graphic_3: Scatter worthChange 
graphic_3 = df1.plot("position", " worthChange millions USD", kind="scatter")
plt.savefig("scatter position-worthchange")

# %%
#Graphic_4: Wealth comparison between genders
genders_wealth_comparison = df1.groupby('gender')['worth BUSD'].sum().sort_values(ascending=False)/100
gender = ['Male', 'Female', 'None']
colors = ['skyblue', 'grey', 'white']
genders_wealth_comparison.plot(kind='pie', labels = gender, colors = colors, startangle=45, shadow=False, figsize=(16,8),  autopct='%.2f%%')
plt.title('Wealth comparison between genders')
plt.savefig("Wealth comparison between genders")

# %%
#Graphic_5: Wealth comparison between countries 
countries_wealth_comparison = df2.groupby(['country', 'worth BUSD']).agg(['count', 'mean'])
fig = plt.figure(figsize=(50,50))
df1.country[df2.position].value_counts(normalize = True).plot(kind='barh', alpha=0.5)
plt.title('Wealth comparison between countries')
plt.savefig("Wealth comparison between countries")

# %%
#Graphic_6: Number of billionaires per country

colors = ['grey', 'mediumvioletred', 'gold', 'orangered', 'yellowgreen', 'r', 'skyblue', 'navy', 'grey', 'black']
df2['country'].value_counts()[:15].plot(kind='bar', width=0.9, figsize=(20,10), color = colors)
plt.xlabel('Country (Top 30)')
plt.ylabel('Number of billionaires')
plt.title('Number of billionaires per country')
plt.savefig("Number of billionaires per country")
