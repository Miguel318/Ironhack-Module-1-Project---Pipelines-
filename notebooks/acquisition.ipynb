# %%
#Import libraries: 
import sqlite3
import pandas as pd

# %%
def read_sql_table(path,table):
    df = sqlite3.connect(path)
    df_table = pd.read_sql_query('SELECT * FROM '+table,df)
    return df_table

# %%
def read_and_merge(path):
    df_business_info = read_sql_table(path, 'business_info')
    df_personal_info = read_sql_table(path, 'personal_info')
    df_rank_info = read_sql_table(path, 'rank_info')
    df4 = pd.merge(df_business_info, df_personal_info, on=['id', 'id'])
    df_dirt = pd.merge(df4, df_rank_info, on=['id', 'id'])
    df_dirt.to_csv('/Users/MIGUEL/Desktop/CLAB1/Ironhack-Module-1-Project---Pipelines-/data/df_dirt.csv', index=False)
    return df_dirt

# %%
df_adquired = read_and_merge('/Users/MIGUEL/Desktop/CLAB1/Ironhack-Module-1-Project---Pipelines-/data/raw/Miguel318.db')
display(df_adquired)
# Out:
#         id  Unnamed: 0_x                                           Source  \
# 0     4656            52                           Technology  ==> Amazon
# 1     1874            53                        Technology  ==> Microsoft
# 2     6703            54  Finance and Investments  ==> Berkshire Hathaway
# 3     2637            55                       Fashion & Retail  ==> LVMH
# 4     8242            56                         Technology  ==> Facebook
# ...    ...           ...                                              ...
# 2203  1711          2255     Fashion & Retail  ==> fashion, entertainment
# 2204  3538          2256          Manufacturing  ==> electrical equipment
# 2205  7797          2257          Manufacturing  ==> electrical equipment
# 2206  3123          2258        Manufacturing  ==> printed circuit boards
# 2207  7030          2259                     Diversified  ==> diversified
#
#            worth          worthChange realTimeWorth  realTimePosition  \
# 0     112.0 BUSD     0.0 millions USD          None                 1
# 1      90.0 BUSD  -0.001 millions USD          None                 2
# 2      84.0 BUSD  -0.002 millions USD          None                 3
# 3      72.0 BUSD     0.0 millions USD          None                 4
# 4      71.0 BUSD     0.0 millions USD          None                 5
# ...          ...                  ...           ...               ...
# 2203    1.0 BUSD     0.0 millions USD          None              2134
# 2204    1.0 BUSD     nan millions USD          None              2134
# 2205    1.0 BUSD     0.0 millions USD          None              1856
# 2206    1.0 BUSD     0.0 millions USD          None              1978
# 2207    1.0 BUSD     nan millions USD          None              1978
#
#         lastName           age  Unnamed: 0_y gender        country  \
# 0          bEZOS  54 years old            52      M           None
# 1          gATES  62 years old            53   None  United States
# 2        bufFETT  87 years old            54      M  United States
# 3        arnAULt  69 years old            55   None           None
# 4     zUCKERBERG          1985            56      M           None
# ...          ...           ...           ...    ...            ...
# 2203        ZHAO  51 years old          2255   None          China
# 2204        zhOU  55 years old          2256      M           None
# 2205         ZHU  51 years old          2257   None          China
# 2206        ZHUO  52 years old          2258      F           None
# 2207       zoRLU  54 years old          2259   None           None
#
#                                                   image             name  \
# 0     https://specials-images.forbesimg.com/imageser...       jEFF BEZOS
# 1     https://specials-images.forbesimg.com/imageser...       bill GAtes
# 2     https://specials-images.forbesimg.com/imageser...   WARREN BUFFETt
# 3     https://specials-images.forbesimg.com/imageser...  bernaRD ARNAULT
# 4     https://specials-images.forbesimg.com/imageser...  maRK ZUCKERBERG
# ...                                                 ...              ...
# 2203  https://specials-images.forbesimg.com/imageser...   zhao xiAOQIang
# 2204  https://specials-images.forbesimg.com/imageser...  zhou LIANGZHang
# 2205  https://specials-images.forbesimg.com/imageser...     zHU XINGMing
# 2206  https://specials-images.forbesimg.com/imageser...         ZHUO JUN
# 2207  https://specials-images.forbesimg.com/imageser...      olguN ZORLU
#
#       position  Unnamed: 0
# 0          1.0          52
# 1          2.0          53
# 2          3.0          54
# 3          4.0          55
# 4          5.0          56
# ...        ...         ...
# 2203    2204.0        2255
# 2204    2205.0        2256
# 2205    2206.0        2257
# 2206    2207.0        2258
# 2207    2208.0        2259
#
# [2208 rows x 16 columns]

# %%
#Extracting database: 

df = sqlite3.connect('/Users/MIGUEL/Desktop/CLAB1/Ironhack-Module-1-Project---Pipelines-/data/raw/Miguel318.db')

# %%
#Extracting tables from the database:
df_business_info = pd.read_sql_query("SELECT * FROM business_info", df)
df_personal_info = pd.read_sql_query("SELECT * FROM personal_info", df)
df_rank_info = pd.read_sql_query("SELECT * FROM rank_info", df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/miniconda3/envs/base2/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1594             else:
# -> 1595                 cur.execute(*args)
#    1596             return cur
#
# OperationalError: no such table: business_info
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-7-5b8dd3eb28f0> in <module>
#       1 #Extracting tables from the database:
# ----> 2 df_business_info = pd.read_sql_query("SELECT * FROM business_info", df)
#       3 df_personal_info = pd.read_sql_query("SELECT * FROM personal_info", df)
#       4 df_rank_info = pd.read_sql_query("SELECT * FROM rank_info", df)
#
# ~/miniconda3/envs/base2/lib/python3.7/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~/miniconda3/envs/base2/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1643
#    1644         args = _convert_params(sql, params)
# -> 1645         cursor = self.execute(*args)
#    1646         columns = [col_desc[0] for col_desc in cursor.description]
#    1647
#
# ~/miniconda3/envs/base2/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1608                 "Execution failed on sql '{sql}': {exc}".format(sql=args[0], exc=exc)
#    1609             )
# -> 1610             raise_with_traceback(ex)
#    1611
#    1612     @staticmethod
#
# ~/miniconda3/envs/base2/lib/python3.7/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#      44     if traceback == Ellipsis:
#      45         _, _, traceback = sys.exc_info()
# ---> 46     raise exc.with_traceback(traceback)
#      47
#      48
#
# ~/miniconda3/envs/base2/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1593                 cur.execute(*args, **kwargs)
#    1594             else:
# -> 1595                 cur.execute(*args)
#    1596             return cur
#    1597         except Exception as exc:
#
# DatabaseError: Execution failed on sql 'SELECT * FROM business_info': no such table: business_info

# %%
#Display tables:
display(df_business_info)
display(df_personal_info)
display(df_rank_info)

# %%
#Merging tables:
df4 = pd.merge(df_business_info, df_personal_info, on=['id', 'id'])
df_dirt = pd.merge(df4, df_rank_info, on=['id', 'id'])

# %%
#Exporting dirty tables to local-data: 
df_dirt.to_csv('/Users/MIGUEL/Desktop/CLAB1/Ironhack-Module-1-Project---Pipelines-/data/df_dirt.csv', index=False)
display(df_dirt)
